# %% [markdown]
# <a href="https://colab.research.google.com/github/mutyala-venkata-vijay-bhargava/ML-Assignment/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


df = pd.read_csv('WineQT.csv')


df['quality'] = df['quality'].apply(lambda x: 1 if x > 6 else 0)


scaler = MinMaxScaler()
df[df.columns[:-1]] = scaler.fit_transform(df[df.columns[:-1]])


df.to_csv('processed_winequality.csv', index=False)


df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788          0.397260         0.00        0.068493   0.106845
# 1       0.283186          0.520548         0.00        0.116438   0.143573
# 2       0.283186          0.438356         0.04        0.095890   0.133556
# 3       0.584071          0.109589         0.56        0.068493   0.105175
# 4       0.247788          0.397260         0.00        0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.149254              0.098940  0.567548  0.606299   0.137725
# 1             0.358209              0.215548  0.494126  0.362205   0.209581
# 2             0.208955              0.169611  0.508811  0.409449   0.191617
# 3             0.238806              0.190813  0.582232  0.330709   0.149701
# 4             0.149254              0.098940  0.567548  0.606299   0.137725
#
#     alcohol  quality  Id
# 0  0.153846      0.0   0
# ...
